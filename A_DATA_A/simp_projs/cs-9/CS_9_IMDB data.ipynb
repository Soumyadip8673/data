# %% [markdown]
# #DATASET link : https://www.kaggle.com/datasets/PromptCloudHQ/imdb-data

# %%
import pandas as pd
import seaborn as sns

# %%
d=pd.read_csv('IMDB-Movie-Data.csv')

# %%
d
# Out:
#      Rank                    Title                     Genre
# 0       1  Guardians of the Galaxy   Action,Adventure,Sci-Fi  \
# 1       2               Prometheus  Adventure,Mystery,Sci-Fi
# 2       3                    Split           Horror,Thriller
# 3       4                     Sing   Animation,Comedy,Family
# 4       5            Suicide Squad  Action,Adventure,Fantasy
# ..    ...                      ...                       ...
# 995   996     Secret in Their Eyes       Crime,Drama,Mystery
# 996   997          Hostel: Part II                    Horror
# 997   998   Step Up 2: The Streets       Drama,Music,Romance
# 998   999             Search Party          Adventure,Comedy
# 999  1000               Nine Lives     Comedy,Family,Fantasy
#
#                                            Description              Director
# 0    A group of intergalactic criminals are forced ...            James Gunn  \
# ...

# %% [markdown]
# **1. Display top 10 rows**

# %%
d.head(10)
# Out:
#    Rank                    Title                       Genre
# 0     1  Guardians of the Galaxy     Action,Adventure,Sci-Fi  \
# 1     2               Prometheus    Adventure,Mystery,Sci-Fi
# 2     3                    Split             Horror,Thriller
# 3     4                     Sing     Animation,Comedy,Family
# 4     5            Suicide Squad    Action,Adventure,Fantasy
# 5     6           The Great Wall    Action,Adventure,Fantasy
# 6     7               La La Land          Comedy,Drama,Music
# 7     8                 Mindhorn                      Comedy
# 8     9       The Lost City of Z  Action,Adventure,Biography
# 9    10               Passengers     Adventure,Drama,Romance
#
#                                          Description              Director
# 0  A group of intergalactic criminals are forced ...            James Gunn  \
# 1  Following clues to the origin of mankind, a te...          Ridley Scott
# ...

# %% [markdown]
# **2. Display bottom 10 rows**

# %%
d.tail(10)
# Out:
#      Rank                           Title                     Genre
# 990   991  Underworld: Rise of the Lycans  Action,Adventure,Fantasy  \
# 991   992                Taare Zameen Par        Drama,Family,Music
# 992   993            Take Me Home Tonight      Comedy,Drama,Romance
# 993   994        Resident Evil: Afterlife   Action,Adventure,Horror
# 994   995                       Project X                    Comedy
# 995   996            Secret in Their Eyes       Crime,Drama,Mystery
# 996   997                 Hostel: Part II                    Horror
# 997   998          Step Up 2: The Streets       Drama,Music,Romance
# 998   999                    Search Party          Adventure,Comedy
# 999  1000                      Nine Lives     Comedy,Family,Fantasy
#
#                                            Description            Director
# 990  An origins story centered on the centuries-old...  Patrick Tatopoulos  \
# ...

# %% [markdown]
# **3. shape of dataset**

# %%
d.shape
# Out:
# (1000, 12)

# %% [markdown]
# **4. information about ds (number of rows,columns,data types of each column and memory requirement)**

# %%
d.info
# Out:
# <bound method DataFrame.info of      Rank                    Title                     Genre
# 0       1  Guardians of the Galaxy   Action,Adventure,Sci-Fi  \
# 1       2               Prometheus  Adventure,Mystery,Sci-Fi
# 2       3                    Split           Horror,Thriller
# 3       4                     Sing   Animation,Comedy,Family
# 4       5            Suicide Squad  Action,Adventure,Fantasy
# ..    ...                      ...                       ...
# 995   996     Secret in Their Eyes       Crime,Drama,Mystery
# 996   997          Hostel: Part II                    Horror
# 997   998   Step Up 2: The Streets       Drama,Music,Romance
# 998   999             Search Party          Adventure,Comedy
# 999  1000               Nine Lives     Comedy,Family,Fantasy
#
#                                            Description              Director
# 0    A group of intergalactic criminals are forced ...            James Gunn  \
# ...

# %% [markdown]
# **5. Check null values in ds**

# %%
d.isnull().sum()
# Out:
# Rank                    0
# Title                   0
# Genre                   0
# Description             0
# Director                0
# Actors                  0
# Year                    0
# Runtime (Minutes)       0
# Rating                  0
# Votes                   0
# Revenue (Millions)    128
# Metascore              64
# dtype: int64

# %%
#visualizing with heatmap
sns.heatmap(d.isnull())
# Out:
# <Axes: >

# %% [markdown]
# **6. drop all the missing values**

# %%
newd=d.dropna(axis=0)

# %%
newd
# Out:
#      Rank                     Title                     Genre
# 0       1   Guardians of the Galaxy   Action,Adventure,Sci-Fi  \
# 1       2                Prometheus  Adventure,Mystery,Sci-Fi
# 2       3                     Split           Horror,Thriller
# 3       4                      Sing   Animation,Comedy,Family
# 4       5             Suicide Squad  Action,Adventure,Fantasy
# ..    ...                       ...                       ...
# 993   994  Resident Evil: Afterlife   Action,Adventure,Horror
# 994   995                 Project X                    Comedy
# 996   997           Hostel: Part II                    Horror
# 997   998    Step Up 2: The Streets       Drama,Music,Romance
# 999  1000                Nine Lives     Comedy,Family,Fantasy
#
#                                            Description              Director
# 0    A group of intergalactic criminals are forced ...            James Gunn  \
# ...

# %% [markdown]
# **7. check for duplicate data**

# %%
dup_d=d.duplicated().any()

# %%
dup_d
# Out:
# False

# %%
print("Are there any duplicate data in the ds ?",dup_d)
# Out:
# Are there any duplicate data in the ds ? False

# %%
redup_d=d.drop_duplicates()
redup_d
# Out:
#      Rank                    Title                     Genre
# 0       1  Guardians of the Galaxy   Action,Adventure,Sci-Fi  \
# 1       2               Prometheus  Adventure,Mystery,Sci-Fi
# 2       3                    Split           Horror,Thriller
# 3       4                     Sing   Animation,Comedy,Family
# 4       5            Suicide Squad  Action,Adventure,Fantasy
# ..    ...                      ...                       ...
# 995   996     Secret in Their Eyes       Crime,Drama,Mystery
# 996   997          Hostel: Part II                    Horror
# 997   998   Step Up 2: The Streets       Drama,Music,Romance
# 998   999             Search Party          Adventure,Comedy
# 999  1000               Nine Lives     Comedy,Family,Fantasy
#
#                                            Description              Director
# 0    A group of intergalactic criminals are forced ...            James Gunn  \
# ...

# %% [markdown]
# **8. overall statistics about the ds**

# %%
d.describe()
# Out:
#               Rank         Year  Runtime (Minutes)       Rating         Votes
# count  1000.000000  1000.000000        1000.000000  1000.000000  1.000000e+03  \
# mean    500.500000  2012.783000         113.172000     6.723200  1.698083e+05
# std     288.819436     3.205962          18.810908     0.945429  1.887626e+05
# min       1.000000  2006.000000          66.000000     1.900000  6.100000e+01
# 25%     250.750000  2010.000000         100.000000     6.200000  3.630900e+04
# 50%     500.500000  2014.000000         111.000000     6.800000  1.107990e+05
# 75%     750.250000  2016.000000         123.000000     7.400000  2.399098e+05
# max    1000.000000  2016.000000         191.000000     9.000000  1.791916e+06
#
#        Revenue (Millions)   Metascore
# count          872.000000  936.000000
# mean            82.956376   58.985043
# std            103.253540   17.194757
# min              0.000000   11.000000
# 25%             13.270000   47.000000
# ...

# %%
d.describe(include='all')
# Out:
#                Rank     Title                    Genre
# count   1000.000000      1000                     1000  \
# unique          NaN       999                      207
# top             NaN  The Host  Action,Adventure,Sci-Fi
# freq            NaN         2                       50
# mean     500.500000       NaN                      NaN
# std      288.819436       NaN                      NaN
# min        1.000000       NaN                      NaN
# 25%      250.750000       NaN                      NaN
# 50%      500.500000       NaN                      NaN
# 75%      750.250000       NaN                      NaN
# max     1000.000000       NaN                      NaN
#
#                                               Description      Director
# count                                                1000          1000  \
# unique                                               1000           644
# top     A group of intergalactic criminals are forced ...  Ridley Scott
# ...

# %% [markdown]
# **9. title of the movie having runtime >= 180 minutes**

# %%
d[d['Runtime (Minutes)']>=180]['Title']
# Out:
# 82     The Wolf of Wall Street
# 88           The Hateful Eight
# 311             La vie d'Adèle
# 828                 Grindhouse
# 965              Inland Empire
# Name: Title, dtype: object

# %% [markdown]
# **10. in which year there was highest average voting**

# %%
d.columns
# Out:
# Index(['Rank', 'Title', 'Genre', 'Description', 'Director', 'Actors', 'Year',
#        'Runtime (Minutes)', 'Rating', 'Votes', 'Revenue (Millions)',
#        'Metascore'],
#       dtype='object')

# %%
d.groupby('Year')['Votes'].mean().sort_values(ascending=False)
# Out:
# Year
# 2012    285226.093750
# 2008    275505.384615
# 2006    269289.954545
# 2009    255780.647059
# 2010    252782.316667
# 2007    244331.037736
# 2011    240790.301587
# 2013    219049.648352
# 2014    203930.224490
# 2015    115726.220472
# 2016     48591.754209
# Name: Votes, dtype: float64

# %%
#visualization
sns.barplot(x='Year',y='Votes',data=d)
# Out:
# <Axes: xlabel='Year', ylabel='Votes'>

# %% [markdown]
# **11. in which year there was highest average revenue?**

# %%
d.columns
# Out:
# Index(['Rank', 'Title', 'Genre', 'Description', 'Director', 'Actors', 'Year',
#        'Runtime (Minutes)', 'Rating', 'Votes', 'Revenue (Millions)',
#        'Metascore'],
#       dtype='object')

# %%
# Out:
# 0      333.13
# 1      126.46
# 2      138.12
# 3      270.32
# 4      325.02
#         ...
# 995       NaN
# 996     17.54
# 997     58.01
# 998       NaN
# 999     19.64
# Name: Revenue (Millions), Length: 1000, dtype: float64

# %%
d.groupby('Year')['Revenue (Millions)'].mean().sort_values(ascending=False)
# Out:
# Year
# 2009    112.601277
# 2012    107.973281
# 2010    105.081579
# 2008     99.082745
# 2007     87.882245
# 2011     87.612258
# 2013     87.121818
# 2006     86.296667
# 2014     85.078723
# 2015     78.355044
# 2016     54.690976
# Name: Revenue (Millions), dtype: float64

# %%
#visualization
sns.barplot(x='Year',y='Revenue (Millions)',data=d)
# Out:
# <Axes: xlabel='Year', ylabel='Revenue (Millions)'>

# %% [markdown]
# **12. Average rating for each director**

# %%
d.columns
# Out:
# Index(['Rank', 'Title', 'Genre', 'Description', 'Director', 'Actors', 'Year',
#        'Runtime (Minutes)', 'Rating', 'Votes', 'Revenue (Millions)',
#        'Metascore'],
#       dtype='object')

# %%
d.groupby('Director')['Rating'].mean().sort_values(ascending=False)
# Out:
# Director
# Nitesh Tiwari        8.80
# Christopher Nolan    8.68
# Olivier Nakache      8.60
# Makoto Shinkai       8.60
# Aamir Khan           8.50
#                      ...
# Micheal Bafaro       3.50
# Jonathan Holbrook    3.20
# Shawn Burkett        2.70
# James Wong           2.70
# Jason Friedberg      1.90
# Name: Rating, Length: 644, dtype: float64

# %% [markdown]
# **13. top 10 lenthy movie title and runtime**

# %%
d.columns
# Out:
# Index(['Rank', 'Title', 'Genre', 'Description', 'Director', 'Actors', 'Year',
#        'Runtime (Minutes)', 'Rating', 'Votes', 'Revenue (Millions)',
#        'Metascore'],
#       dtype='object')
